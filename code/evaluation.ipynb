# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.plot([7,8,9,10,11],[0.3669,0.3616,0.4781,0.4961,0.5048],marker='o',label='32 Filters')
plt.grid()
plt.title('Results')
plt.ylabel('Pearson Correlation')
plt.xlabel('Dilation Layers')
plt.legend()
plt.savefig('result.jpg',dpi=1000)
plt.show()
